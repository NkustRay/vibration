# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
td = pd.read_csv('01_220408_01.csv')
tdL = pd.read_csv('L01_220408_01.csv')
tdN = pd.read_csv('N02_220127_01.csv')

# %%
td
# Out:
#               T         A
# 0      0.000030 -1.374687
# 1      0.000061 -1.289954
# 2      0.000092 -1.212645
# 3      0.000122 -1.161049
# 4      0.000153 -1.131316
# ...         ...       ...
# 16379  0.499878 -1.561404
# 16380  0.499908  0.000000
# 16381  0.499939  0.000000
# 16382  0.499970  0.000000
# 16383  0.500000  0.000000
#
# [16384 rows x 2 columns]

# %%
tdL
# Out:
#               T         A
# 0      0.000030  2.042368
# 1      0.000061  2.036174
# 2      0.000092  2.023916
# 3      0.000122  2.011485
# 4      0.000153  2.002346
# ...         ...       ...
# 16379  0.499878  1.716285
# 16380  0.499908  0.000000
# 16381  0.499939  0.000000
# 16382  0.499970  0.000000
# 16383  0.500000  0.000000
#
# [16384 rows x 2 columns]

# %%
tdN
# Out:
#               T       A
# 0      0.000030  0.0777
# 1      0.000061  0.0622
# 2      0.000092  0.0395
# 3      0.000122  0.0122
# 4      0.000153 -0.0176
# ...         ...     ...
# 16379  0.499878  0.0727
# 16380  0.499908  0.0000
# 16381  0.499939  0.0000
# 16382  0.499970  0.0000
# 16383  0.500000  0.0000
#
# [16384 rows x 2 columns]

# %%
x = td.T
y = td.A

xL = tdL.T
yL = tdL.A

xN = tdN.T
yN = tdN.A

# %%
td.A.plot(); plt.title('Outer'); plt.xlabel('time'); plt.ylabel('mm/s')
plt.grid()

figure = plt.gcf()
figure.set_size_inches(4*3.6, 4)
plt.savefig('Outer.svg')

plt.figure(); plt.title('NoLub'); plt.xlabel('time'); plt.ylabel('mm/s')
tdL.A.plot()
plt.grid()

figure = plt.gcf()
figure.set_size_inches(4*3.6, 4)
plt.savefig('NoLub.svg')

plt.figure(); plt.title('Normal'); plt.xlabel('time'); plt.ylabel('mm/s')
tdN.A.plot()
plt.grid()

figure = plt.gcf()
figure.set_size_inches(4*3.6, 4)
plt.savefig('Normal.svg')
plt.grid()

# %%
plt.xlabel('time')
plt.ylabel('mm/s')
plt.title('CSV data')
td.A.plot()
tdL.A.plot()
tdN.A.plot()

plt.grid()

# figure = plt.gcf()
# figure.set_size_inches(4*3.6, 4)
# plt.savefig('csv data test.svg')

# %%
td.A.plot()
plt.xlabel('time')
plt.ylabel('mm/s')
plt.title('CSV data')
plt.grid()

figure = plt.gcf()
figure.set_size_inches(16, 4)
plt.savefig('csv data test.svg')
plt.savefig('csv data test.pdf')
